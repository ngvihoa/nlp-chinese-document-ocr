# %%
# !nvidia-smi
# !git clone --branch Nhat --single-branch https://github.com/ngvihoa/nlp-chinese-document-ocr.git
# %cd nlp-chinese-document-ocr
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# Cloning into 'nlp-chinese-document-ocr'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 235 (delta 83), reused 197 (delta 54), pack-reused 0 (from 0)
# Receiving objects: 100% (235/235), 39.17 MiB | 29.09 MiB/s, done.
# Resolving deltas: 100% (83/83), done.
# /kaggle/working/nlp-chinese-document-ocr

# %%
# Dùng virtualenv riêng để tránh xung đột với package có sẵn của Kaggle.

# !rm -rf /kaggle/working/post_processing_env
# !python -m pip install -q virtualenv
# !python -m virtualenv /kaggle/working/post_processing_env

# !/kaggle/working/post_processing_env/bin/python -m pip install -q --upgrade pip
# !/kaggle/working/post_processing_env/bin/python -m pip install -q -r requirements.colab.txt

import os
os.environ["PATH"] = "/kaggle/working/post_processing_env/bin:" + os.environ["PATH"]

print("Kaggle segmentation environment is ready")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 42.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.6/470.6 kB 22.5 MB/s eta 0:00:00
# created virtual environment CPython3.12.13.final.0-64-x86_64 in 432ms
#   creator CPython3Posix(dest=/kaggle/working/post_processing_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.1.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator,XonshActivator
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'wrapt'
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'wrapt'
# Kaggle segmentation environment is ready

# %%
# !/kaggle/working/post_processing_env/bin/python -m pip check
# Out:
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'wrapt'
# No broken requirements found.

# %%
from google.colab import auth
auth.authenticate_user()
print('Google authentication completed')
# Out:
# Google authentication completed

# %%
# Điền hai folder ID trước khi chạy. Không ghi OAuth secret vào notebook.
DRIVE_INPUT_FOLDER_ID = 'ID'
DRIVE_OUTPUT_FOLDER_ID = 'ID'
assert not DRIVE_INPUT_FOLDER_ID.startswith('PASTE_')
assert not DRIVE_OUTPUT_FOLDER_ID.startswith('PASTE_')

# %%
# !/kaggle/working/post_processing_env/bin/python scripts/segmentation/run_segmentation_pipeline.py \
  --use-colab-auth \
  --drive-folder-id "{DRIVE_INPUT_FOLDER_ID}" \
  --file-name "HVH_019_clean.txt"
# Out:
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'wrapt'
# [DOWNLOAD] HVH_019_clean.txt
# [UPLOAD] HVH_019_seg.tsv
# [DONE] HVH_019_clean.txt -> HVH_019_seg.tsv | sentences: 2137
